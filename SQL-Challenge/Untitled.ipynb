# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine, inspect
engine = create_engine('postgresql://postgres:Password123@localhost:5432/Homework-09')
connection = engine.connect()

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['employees', 'dept_emp', 'departments', 'dept_manager', 'titles', 'salaries']

# %%
columns = inspector.get_columns('employees')
for c in columns:
    print(c['name'], c["type"])
# Out:
# emp_no INTEGER
# emp_title_id VARCHAR
# birth_date DATE
# first_name VARCHAR
# last_name VARCHAR
# sex VARCHAR
# hire_date DATE

# %%
columns = inspector.get_columns('dept_emp')
for c in columns:
    print(c['name'], c["type"])
# Out:
# emp_no INTEGER
# dept_no VARCHAR

# %%
columns = inspector.get_columns('departments')
for c in columns:
    print(c['name'], c["type"])
# Out:
# dept_no VARCHAR
# dept_name VARCHAR

# %%
columns = inspector.get_columns('dept_manager')
for c in columns:
    print(c['name'], c["type"])
# Out:
# dept_no VARCHAR
# emp_no INTEGER

# %%
columns = inspector.get_columns('titles')
for c in columns:
    print(c['name'], c["type"])
# Out:
# title_id VARCHAR
# title VARCHAR

# %%
columns = inspector.get_columns('salaries')
for c in columns:
    print(c['name'], c["type"])
# Out:
# emp_no INTEGER
# salary INTEGER

# %%
##Base = automap_base()
##Base.prepare(engine, reflect=True)
##salaries = Base.classes.salaries
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'salaries'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-0bcfa6664cd4> in <module>
#       1 Base = automap_base()
#       2 Base.prepare(engine, reflect=True)
# ----> 3 salaries = Base.classes.salaries
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: salaries

# %%
engine.execute('SELECT salary FROM salaries').fetchall()
# Out:
# [(60117,),
#  (65828,),
#  (40006,),
#  (40054,),
#  (78228,),
#  (40000,),
#  (56724,),
#  (46671,),
#  (60929,),
#  (72488,),
#  (42365,),
#  (40000,),
#  (40000,),
#  (46168,),
#  (40000,),
#  (70889,),
#  (71380,),
#  (55881,),
#  (44276,),
#  (40000,),
#  (55025,),
#  (40000,),
#  (47883,),
#  (83733,),
#  (40000,),
#  (47585,),
#  (40000,),
#  (48859,),
#  (63163,),
#  (66956,),
#  (40000,),
#  (48426,),
#  (51258,),
#  (47561,),
#  (41538,),
#  (42819,),
#  (40000,),
#  (40000,),
#  (40000,),
#  (52153,),
#  (56893,),
#  (81662,),
#  (49324,),
#  (40919,),
#  (41971,),
#  (40000,),
#  (54982,),
#  (40000,),
#  (40000,),
#  (74366,),
#  (48817,),
#  (57212,),
#  (67854,),
#  (40000,),
#  (80024,),
#  (48857,),
#  (49616,),
#  (52787,),
#  (71218,),
#  (74686,),
#  (68577,),
#  (55685,),
#  (40000,),
#  (40000,),
#  (40000,),
#  (69736,),
#  (44642,),
#  (87964,),
#  (67932,),
#  (55999,),
#  (40000,),
#  (40000,),
#  (56473,),
#  (61714,),
#  (43815,),
#  (47319,),
# ...

# %%
session = Session(engine)

# %%
Base.classes.keys()
# Out:
# ['employees', 'titles', 'departments']

# %%
Employees = Base.classes.employees

# %%
Titles = Base.classes.titles

# %%
Departments = Base.classes.departments

# %%
session = Session(engine)

# %%
first_row = session.query(Employees).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x286689cc988>,
#  'birth_date': datetime.date(1953, 7, 25),
#  'emp_no': 473302,
#  'last_name': 'Zallocco',
#  'hire_date': datetime.date(1990, 4, 28),
#  'emp_title_id': 's0001',
#  'first_name': 'Hideyuki',
#  'sex': 'M'}

# %%
first_row = session.query(Titles).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x286689ccec8>,
#  'title': 'Staff',
#  'title_id': 's0001'}

# %%
first_row = session.query(Departments).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x286689d9988>,
#  'dept_no': 'd001',
#  'dept_name': 'Marketing'}

# %%
engine.execute(hist(column='salary' FROM salaries').fetchall()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'salaries'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-5a80d26afb39> in <module>
# ----> 1 Salaries = Base.classes.salaries
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: salaries

# %%
salarios = engine.execute('SELECT salary FROM salaries').fetchall()

# %%
salarios
# Out:
# [(60117,),
#  (65828,),
#  (40006,),
#  (40054,),
#  (78228,),
#  (40000,),
#  (56724,),
#  (46671,),
#  (60929,),
#  (72488,),
#  (42365,),
#  (40000,),
#  (40000,),
#  (46168,),
#  (40000,),
#  (70889,),
#  (71380,),
#  (55881,),
#  (44276,),
#  (40000,),
#  (55025,),
#  (40000,),
#  (47883,),
#  (83733,),
#  (40000,),
#  (47585,),
#  (40000,),
#  (48859,),
#  (63163,),
#  (66956,),
#  (40000,),
#  (48426,),
#  (51258,),
#  (47561,),
#  (41538,),
#  (42819,),
#  (40000,),
#  (40000,),
#  (40000,),
#  (52153,),
#  (56893,),
#  (81662,),
#  (49324,),
#  (40919,),
#  (41971,),
#  (40000,),
#  (54982,),
#  (40000,),
#  (40000,),
#  (74366,),
#  (48817,),
#  (57212,),
#  (67854,),
#  (40000,),
#  (80024,),
#  (48857,),
#  (49616,),
#  (52787,),
#  (71218,),
#  (74686,),
#  (68577,),
#  (55685,),
#  (40000,),
#  (40000,),
#  (40000,),
#  (69736,),
#  (44642,),
#  (87964,),
#  (67932,),
#  (55999,),
#  (40000,),
#  (40000,),
#  (56473,),
#  (61714,),
#  (43815,),
#  (47319,),
# ...

# %%
compensation = [salario[0] for salario in salarios]

# %%
compensation
# Out:
# [60117,
#  65828,
#  40006,
#  40054,
#  78228,
#  40000,
#  56724,
#  46671,
#  60929,
#  72488,
#  42365,
#  40000,
#  40000,
#  46168,
#  40000,
#  70889,
#  71380,
#  55881,
#  44276,
#  40000,
#  55025,
#  40000,
#  47883,
#  83733,
#  40000,
#  47585,
#  40000,
#  48859,
#  63163,
#  66956,
#  40000,
#  48426,
#  51258,
#  47561,
#  41538,
#  42819,
#  40000,
#  40000,
#  40000,
#  52153,
#  56893,
#  81662,
#  49324,
#  40919,
#  41971,
#  40000,
#  54982,
#  40000,
#  40000,
#  74366,
#  48817,
#  57212,
#  67854,
#  40000,
#  80024,
#  48857,
#  49616,
#  52787,
#  71218,
#  74686,
#  68577,
#  55685,
#  40000,
#  40000,
#  40000,
#  69736,
#  44642,
#  87964,
#  67932,
#  55999,
#  40000,
#  40000,
#  56473,
#  61714,
#  43815,
#  47319,
#  40000,
#  47280,
#  53492,
#  54916,
#  55786,
#  48935,
#  40000,
#  69811,
#  40000,
#  81613,
#  96750,
#  65957,
#  56469,
#  44978,
#  40000,
#  53977,
#  67856,
#  58001,
#  63668,
#  61395,
#  44886,
#  40000,
#  68781,
#  54398,
# ...

# %%
compensation[0]
# Out:
# 60117

# %%
compensation[1]
# Out:
# 65828

# %%
plt.hist(compensation)
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.savefig('histogram to visualize the most common salary ranges for employees.jpg', bbox_inches = 'tight')
plt.show()

# %%
title_averages = session.query(engine).group_by(title).order_by(title).all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-40aec01d5483> in <module>
# ----> 1 title_averages = session.query(engine).group_by(title).order_by(title).all()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\session.py in query(self, *entities, **kwargs)
#    1582         :class:`.Session`."""
#    1583
# -> 1584         return self._query_cls(entities, self, **kwargs)
#    1585
#    1586     @property
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\query.py in __init__(self, entities, session)
#     197         self.session = session
#     198         self._polymorphic_adapters = {}
# --> 199         self._set_entities(entities)
#     200
#     201     def _set_entities(self, entities, entity_wrapper=None):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\orm\query.py in _set_entities(self, entities, entity_wrapper)
#     223         if entities != ():
# ...
